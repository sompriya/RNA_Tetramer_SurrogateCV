# %%
#AAAA our 3runs from opes from MultiT
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate
from mlcolvar.utils import plot
data_9_7ns = np.loadtxt('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_9.7ns/fes_our_9.7ns.dat')
data_9_9ns = np.loadtxt('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_9.9ns/fes_our_9.9ns.dat')
data_10ns = np.loadtxt('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_10ns/fes_our_10ns.dat')

x_9_7ns = data_9_7ns[:, 0]  # First column 
y_9_7ns = data_9_7ns[:, 1]  # Second column 
z_9_7ns = data_9_7ns[:, 2]  # Third column 

x_9_9ns = data_9_9ns[:, 0]  # First column 
y_9_9ns = data_9_9ns[:, 1]  # Second column 
z_9_9ns = data_9_9ns[:, 2]  # Third column 

x_10ns = data_10ns[:, 0]  # First column 
y_10ns = data_10ns[:, 1]  # Second column 
z_10ns = data_10ns[:, 2]  # Third column 

x_mean = np.mean([x_9_7ns,x_9_9ns,x_10ns], axis=0)
y_mean = np.mean([y_9_7ns,y_9_9ns,y_10ns], axis=0)
z_mean = np.mean([z_9_7ns,z_9_9ns,z_10ns], axis=0)
print(x_mean)
print(y_mean)
print(z_mean)

# Stack the arrays into a single 2D array with three columns
data = np.column_stack((x_mean, y_mean, z_mean))

# Save to a file
np.savetxt('mean_values_withoutstatic_aaaa_9.7_9.9_10ns.dat', data, header='lassoCV_node0 lassoCV_node1 fe', fmt='%.6f', delimiter='\t')



def plot_2d_fes(filename,max_fes,n_contour,xlabel='x',ylabel='y',cbar_label='Free Energy (kJ/mol)',cmap='fessa'):
    N = 200 #number of points for plotting/interpolation
    x, y, z = np.genfromtxt(filename, unpack=True)

    xi = np.linspace(x.min(), x.max(), N)
    yi = np.linspace(y.min(), y.max(), N)
    zi = scipy.interpolate.griddata((x, y), z, (xi[None,:], yi[:,None]))

    X, Y = np.meshgrid(xi, yi)

    cp = plt.contourf(X, Y, zi, levels=np.linspace(0,max_fes,n_contour-1), cmap=cmap)
    plt.clim(0.0,max_fes)
    cbar = plt.colorbar(cp)
    cbar.set_label(cbar_label,fontsize=16)
    plt.xlabel(xlabel,fontsize=16)
    plt.ylabel(ylabel,fontsize=16)
    


plot_2d_fes('mean_values_withoutstatic_aaaa_9.7_9.9_10ns.dat',20,20,xlabel=r'Deep-TICA_lasso1',ylabel=r'Deep-TICA_lasso2',cmap='fessa')

plt.xlim(-0.9,1.2)
plt.ylim(-1.2,0.75)
plt.savefig('fes_ourcv.png',dpi=300,bbox_inches='tight')
plt.show()
# Out:
# [-0.93814167 -0.915611   -0.89308    ...  1.26986833  1.29239933
#   1.31493   ]
# [-1.28202367 -1.28202367 -1.28202367 ...  1.05651833  1.05651833
#   1.05651833]
# [167.565808   128.62365267  99.82456067 ... 350.274255   419.94354233
#  495.55201533]

# %%
#AAAA our multiTCV in deshaw
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate
from mlcolvar.utils import plot
def plot_2d_fes(filename,max_fes,n_contour,xlabel='x',ylabel='y',cbar_label='Free Energy (kJ/mol)',cmap='fessa'):
    N = 200 #number of points for plotting/interpolation
    x, y, z = np.genfromtxt(filename, unpack=True)

    xi = np.linspace(x.min(), x.max(), N)
    yi = np.linspace(y.min(), y.max(), N)
    zi = scipy.interpolate.griddata((x, y), z, (xi[None,:], yi[:,None]))

    X, Y = np.meshgrid(xi, yi)

    cp = plt.contourf(X, Y, zi, levels=np.linspace(0,max_fes,n_contour-1), cmap=cmap)
    plt.clim(0.0,max_fes)
    cbar = plt.colorbar(cp)
    cbar.set_label(cbar_label,fontsize=16)
    plt.xlabel(xlabel,fontsize=16)
    plt.ylabel(ylabel,fontsize=16)
    


plot_2d_fes('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/DE_Shaw_analysis_mod_final/fes_deshaw_ourmultiTCV_0.025.dat',20,20,xlabel=r'Deep-TICA_lasso1',ylabel=r'Deep-TICA_lasso2',cmap='fessa')

plt.xlim(-0.9,1.2)
plt.ylim(-1.2,0.75)
plt.savefig('fes_ourcv_indeshaw.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
def compute_fes(
    X,
    temp=300,
    kbt=None,
    num_samples=100,
    bounds=None,
    bandwidth=0.01,
    kernel="gaussian",
    weights=None,
    scale_by=None,
    blocks=1,
    fes_to_zero=None,
    plot=False,
    plot_max_fes=None,
    ax=None,
    backend=None,
    eps=0,
):
    """Compute the Free Energy Surface along the given variables.

    Parameters
    ----------
    X : array-like, list of arrays
        data
    temp : float, optional
        temperature, by default 300
    kbt : float, optional
        temperature in energy units, by default None
    num_samples : int, optional
        number of points used along each direction, by default 100
    bounds : list of lists, optional
        limit the calculation of the FES to a region, by default equal to the range of values
    bandwidth : float, optional
        Bandwidth use for the kernels, by default 0.1.
    kernel: string, optional
        Kernel type, by default 'gaussian'.
    weights : array, optional
        array of samples weights, by default None
    scale_by : string, optional
        Standardize each variable by its standard deviation (`std`) or by its range of values, by default None
    blocks : int, optional
        number of blocks to be used, by default 1
    fes_to_zero: int, optional
        index of the array where to shift the FES to zero (if none the minimum is set to zero)
    plot : bool, optional
        Plot the results (only available for 1D and 2D FES), by default False
    plot_max_fes : float, optional
        Maximum value of the FES to be plotted, by default None
    ax : matplotlib axis, optional
        Axis where to plot, default create new figure
    backend: string, optional
        Specify the backend for KDE ("KDEpy" or "sklearn")
    eps: float, optional
        Add an epsilon in the argument of the log

    Returns
    -------
    fes: np.array
        free energy
    grid: np.array or list of arrays (>1D)
        grid points for plotting
    bounds: list
        bounds along each variable
    std: np.array
        (weighted) standard deviation along the blocks (only if blocks>1)

    Notes
    -----
    - This function uses sklearn.neighbors.KernelDensity function to construct the estimate of the FES (https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KernelDensity.html). You can specify all the kernels supported.

    - Note that if ``scale_by`` is not none, the bandwidth is not rescaled as well. So if using ``scale_by='range'`` a bandwidth of 0.01 corresponds to a 1/100 of the range of values assumed by the variable.

    - If blocks>1 a (weighted) block analyis is performed [1], which allows also to obtain an estimate of the uncertainty.

    [1] Invernizzi, Piaggi and Parrinello, PRX, 2020,10,4

    """
    # check backend for KDE
    if kdelib is None:
        raise NotImplementedError(
            "The function compute_fes requires either KDEpy (fast) or scikit-learn (slow) to work."
        )
    if kdelib == "sklearn":
        warnings.warn(
            "Warning: KDEpy is not installed, falling back to scikit-learn for kernel density estimation (very slow for d>1)."
        )

    if backend == "sklearn":
        from sklearn.neighbors import KernelDensity
    elif backend is None:
        backend = kdelib

    # temperature
    if kbt is None:
        kb = 0.00831441
        kbt = kb * temp

    # dataset
    if PANDAS_IS_INSTALLED:
        if type(X) == pd.DataFrame:
            X = X.values
    if type(X) == list:
        X = np.vstack(X).T
    elif type(X) == torch.Tensor:
        X = X.numpy()
    if X.ndim == 1:
        X = X.reshape([-1, 1])

    # div
    nsamples = X.shape[0]
    dim = X.shape[1]

    # weights
    if weights is None:
        weights = np.ones(nsamples)
    else:
        assert weights.ndim == 1
        assert weights.shape[0] == nsamples

    # rescale
    if scale_by is not None:
        if scale_by == "std":
            scale = X.std(axis=0)
        elif scale_by == "range":
            scale = X.max(axis=0) - X.min(axis=0)
        elif type(scale_by) == list:
            scale = np.asarray(scale_by)
        X = np.copy(X)
        X /= scale

    # eval points
    offset = 1e-3
    if dim == 1:
        if bounds is None:
            bounds = (X[:, 0].min() - offset, X[:, 0].max() + offset)
        grid = np.linspace(bounds[0], bounds[1], num_samples)
        positions = grid.reshape([-1, 1])
    else:
        if bounds is None:
            bounds = [
                (X[:, i].min() - offset, X[:, i].max() + offset) for i in range(dim)
            ]
        grid_list = [np.linspace(b[0], b[1], num_samples) for b in bounds]
        grid = np.meshgrid(*grid_list)
        positions = np.vstack([g.ravel() for g in grid]).T

    # divide in blocks
    X_b = np.array_split(X, blocks)
    w_b = np.array_split(weights, blocks)

    O_i, W_i = [], []  # values per block
    # block average
    for i in range(blocks):
        # data of each block
        X_i = X_b[i]
        w_i = w_b[i]

        # fit
        if backend == "KDEpy":
            kde = FFTKDE(bw=bandwidth, kernel=kernel)
            kde.fit(X_i, weights=w_i)

            if dim == 1:
                pos = [grid]
            else:
                pos = grid_list

            # pdf --> fes
            fes = (
                -kbt
                * np.log(kde.evaluate(cartesian(pos)) + eps)
                .reshape([num_samples for i in range(dim)])
                .T
            )

        elif backend == "sklearn":
            kde = KernelDensity(bandwidth=bandwidth, kernel=kernel)
            kde.fit(X_i, sample_weight=w_i)

            # logpdf --> fes
            fes = -kbt * kde.score_samples(positions).reshape(
                [num_samples for i in range(dim)]
            )

        if fes_to_zero is not None:
            fes -= fes[fes_to_zero]
        else:
            fes -= fes.min()

        # result for each block
        O_i.append(fes)
        W_i.append(np.sum(w_i))

    O_i = np.asarray(O_i)
    W_i = np.asarray(W_i)

    # compute avg and std
    if blocks > 1:
        # weighted average
        O = np.dot(O_i.T, W_i) / np.sum(W_i)
        # weighted std
        dev = O_i - O
        blocks_eff = (np.sum(W_i)) ** 2 / (np.sum(W_i**2))
        variance = (
            blocks_eff / (blocks_eff - 1) * (np.dot((dev**2).T, W_i)) / (np.sum(W_i))
        )
        error = np.sqrt(variance / blocks_eff)
    else:
        O = O_i[0]
        error = None

    # rescale back
    if scale_by is not None:
        if dim == 1:
            bounds = (bounds[0] * scale[0], bounds[1] * scale[0])
            grid *= scale
        else:
            bounds = [
                (bounds[i][0] * scale[i], bounds[i][1] * scale[i]) for i in range(dim)
            ]
            for i in range(dim):
                grid[i] *= scale[i]

    # Plot
    if plot:
        if ax is None:
            fig, ax = plt.subplots()
        if dim == 1:
            fes2 = np.copy(O)
            if plot_max_fes is not None:
                fes2[fes2 > plot_max_fes] = np.nan
            if blocks > 1:
                ax.errorbar(grid, fes2, error)
            else:
                ax.plot(grid, fes2)
            ax.set_ylabel("FES")
        elif dim == 2:
            fes2 = np.copy(O)
            if plot_max_fes is not None:
                fes2[fes2 > plot_max_fes] = np.nan
            extent = [item for sublist in bounds for item in sublist]
            pp = ax.contourf(fes2, cmap="coolwarm", extent=extent)  # ,vmax=max_fes)
            cbar = plt.colorbar(pp, ax=ax)
            cbar.set_label("FES")

    return fes, grid, bounds, error

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes
import pandas as pd


# load colvar files containing weights of the OPES simulations as well as the driver with the input features
opes = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_10ns_mod_final/COLVAR',
    start=100000, stop=1000000, stride=10)

feat = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_10ns_mod_final/COLVAR_driver',
    start=10000, stop=100000, stride=1)



bias = opes.filter(regex='.bias').values.sum(axis=1)

cv = feat.filter(regex='lassoCV_node0|lassoCV_node1').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

fig,ax = plt.subplots(1,1,figsize=(6,5),dpi=100)



fes_10ns,grid_10ns,bounds_10ns,error_10ns = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=True, plot_max_fes=20, ax = ax, eps=1e-10)
print(fes_10ns.shape)
ax.set_xlabel('Deep-TICA_lass0 1')
ax.set_ylabel('Deep-TICA_lasso 2')
plt.show()
# Out:
# (100, 100)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes
import pandas as pd


# load colvar files containing weights of the OPES simulations as well as the driver with the input features
opes = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_9.7ns_mod_final/COLVAR',
    start=100000, stop=1000000, stride=10)

feat = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_9.7ns_mod_final/COLVAR_driver',
    start=10000, stop=100000, stride=1)



bias = opes.filter(regex='.bias').values.sum(axis=1)

cv = feat.filter(regex='lassoCV_node0|lassoCV_node1').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

fig,ax = plt.subplots(1,1,figsize=(6,5),dpi=100)



fes_9_7ns,grid_9_7ns,bounds_9_7ns,error_9_7ns = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=True, plot_max_fes=20, ax = ax, eps=1e-10)

ax.set_xlabel('Deep-TICA_lass0 1')
ax.set_ylabel('Deep-TICA_lasso 2')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes
import pandas as pd


# load colvar files containing weights of the OPES simulations as well as the driver with the input features
opes = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_9.9ns_mod_final/COLVAR',
    start=100000, stop=1000000, stride=10)

feat = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_9.9ns_mod_final/COLVAR_driver',
    start=10000, stop=100000, stride=1)



bias = opes.filter(regex='.bias').values.sum(axis=1)

cv = feat.filter(regex='lassoCV_node0|lassoCV_node1').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

fig,ax = plt.subplots(1,1,figsize=(6,5),dpi=100)



fes_9_9ns,grid_9_9ns,bounds_9_9ns,error_9_9ns = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=True, plot_max_fes=20, ax = ax, eps=1e-10)

ax.set_xlabel('Deep-TICA_lass0 1')
ax.set_ylabel('Deep-TICA_lasso 2')
plt.show()

# %%
fes_mean = (fes_10ns + fes_9_7ns + fes_9_9ns)/3
fes_mean -= np.min(fes_mean)


pp = plt.contourf(fes_mean, cmap="fessa", vmax=20, levels=[2*i for i in range(11)],extent=(grid_9_9ns[0][0,:].min(),grid_9_9ns[0][0,:].max(),grid_9_9ns[1][:,0].min(),grid_9_9ns[1][:,0].max()))
cbar = plt.colorbar(pp)
plt.xlim(-0.9,1.2)
plt.ylim(-1.2,0.75)
cbar.set_label("FES")
plt.xlabel("Deep-TICA Lasso1")  # Set x-axis label
plt.ylabel("Deep-TICA Lasso2")  
plt.savefig('fes_ourcv_in opes from equl_deshaw_mod.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes

#df = load_dataframe('COLVAR',start=50000,stop=1279880,stride=1)
df = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_10ns/COLVAR',stride=1,start=100000,stop=1000000)

bias = df.filter(regex='opes.bias').values.sum(axis=1)

cv = df.filter(regex='lassoCV_node0|lassoCV_node1').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

fig,ax = plt.subplots(1,1,figsize=(6,5),dpi=100)



fes_10ns_multiT,grid_10ns_multiT,bounds_10ns_multiT,error_10ns_multiT = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=True, plot_max_fes=20, ax = ax, eps=1e-10)

ax.set_xlabel('Deep-TICA_lass0 1')
ax.set_ylabel('Deep-TICA_lasso 2')
plt.show()
# Out:
# /home/sompriya/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# /home/sompriya/.local/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/sompriya/.local/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes

#df = load_dataframe('COLVAR',start=50000,stop=1279880,stride=1)
df = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_9.7ns/COLVAR',stride=1,start=100000,stop=1000000)

bias = df.filter(regex='opes.bias').values.sum(axis=1)

cv = df.filter(regex='lassoCV_node0|lassoCV_node1').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

fig,ax = plt.subplots(1,1,figsize=(6,5),dpi=100)



fes_9_7ns_multiT,grid_9_7ns_multiT,bounds_9_7ns_multiT,error_9_7ns_multiT = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=True, plot_max_fes=20, ax = ax, eps=1e-10)

ax.set_xlabel('Deep-TICA_lass0 1')
ax.set_ylabel('Deep-TICA_lasso 2')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes

#df = load_dataframe('COLVAR',start=50000,stop=1279880,stride=1)
df = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_9.9ns/COLVAR',stride=1,start=100000,stop=1000000)

bias = df.filter(regex='opes.bias').values.sum(axis=1)

cv = df.filter(regex='lassoCV_node0|lassoCV_node1').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

fig,ax = plt.subplots(1,1,figsize=(6,5),dpi=100)



fes_9_9ns_multiT,grid_9_9ns_multiT,bounds_9_9ns_multiT,error_9_9ns_multiT = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=True, plot_max_fes=20, ax = ax, eps=1e-10)

ax.set_xlabel('Deep-TICA_lass0 1')
ax.set_ylabel('Deep-TICA_lasso 2')
plt.show()

# %%
fes_mean_multiT = (fes_10ns_multiT + fes_9_7ns_multiT + fes_9_9ns_multiT)/3
fes_mean_multiT -= np.min(fes_mean_multiT)

x_grid = grid_9_9ns_multiT[0][0]
y_grid = grid_9_9ns_multiT[1][:,0]
print(fes_mean_multiT.shape)
print(grid_9_9ns_multiT[0],grid_9_9ns_multiT[1])
print(x_grid,y_grid)

f1 = open('fes_2d_test.dat','w')
print('#! FIELDS lassoCV_node0 lassoCV_node1 file.free',file=f1)
for j in range(len(y_grid)):
    for i in range(len(x_grid)):
        print(x_grid[i],y_grid[j],fes_mean_multiT[j,i],file=f1)
f1.close()
#np.savetxt("fes_mean_multiT.dat", fes_mean_multiT, fmt="%.6f")
# Out:
# (100, 100)
# [[-0.87888601 -0.85678121 -0.83467641 ...  1.26527941  1.28738421
#    1.30948901]
#  [-0.87888601 -0.85678121 -0.83467641 ...  1.26527941  1.28738421
#    1.30948901]
#  [-0.87888601 -0.85678121 -0.83467641 ...  1.26527941  1.28738421
#    1.30948901]
#  ...
#  [-0.87888601 -0.85678121 -0.83467641 ...  1.26527941  1.28738421
#    1.30948901]
#  [-0.87888601 -0.85678121 -0.83467641 ...  1.26527941  1.28738421
#    1.30948901]
#  [-0.87888601 -0.85678121 -0.83467641 ...  1.26527941  1.28738421
#    1.30948901]] [[-1.26714511 -1.26714511 -1.26714511 ... -1.26714511 -1.26714511
#   -1.26714511]
#  [-1.2435717  -1.2435717  -1.2435717  ... -1.2435717  -1.2435717
#   -1.2435717 ]
#  [-1.2199983  -1.2199983  -1.2199983  ... -1.2199983  -1.2199983
#   -1.2199983 ]
#  ...
#  [ 1.0194753   1.0194753   1.0194753  ...  1.0194753   1.0194753
#    1.0194753 ]
#  [ 1.0430487   1.0430487   1.0430487  ...  1.0430487   1.0430487
#    1.0430487 ]
# ...

# %%
import scipy
def plot_2d_fes(filename,max_fes,n_contour,xlabel='x',ylabel='y',cbar_label='Free Energy (kJ/mol)',cmap='fessa'):
    N = 200 #number of points for plotting/interpolation
    x, y, z = np.genfromtxt(filename, unpack=True)

    xi = np.linspace(x.min(), x.max(), N)
    yi = np.linspace(y.min(), y.max(), N)
    zi = scipy.interpolate.griddata((x, y), z, (xi[None,:], yi[:,None]))

    X, Y = np.meshgrid(xi, yi)

    cp = plt.contourf(X, Y, zi, levels=np.linspace(0,max_fes,n_contour-1), cmap=cmap)
    plt.clim(0.0,max_fes)
    cbar = plt.colorbar(cp)
    cbar.set_label(cbar_label,fontsize=16)
    plt.xlabel(xlabel,fontsize=16)
    plt.ylabel(ylabel,fontsize=16)
    


plot_2d_fes('fes_2d_test.dat',20,20,xlabel=r'Deep-TICA_lasso1',ylabel=r'Deep-TICA_lasso2',cmap='fessa')

plt.xlim(-0.9,1.2)
plt.ylim(-1.2,0.75)
# Out:
# (-1.2, 0.75)

# %%
fes_mean_multiT = (fes_10ns_multiT + fes_9_7ns_multiT + fes_9_9ns_multiT)/3
fes_mean_multiT -= np.min(fes_mean_multiT)
np.savetxt("fes_mean_multiT.dat", fes_mean_multiT, fmt="%.6f")

pp = plt.contourf(fes_mean_multiT, cmap="fessa", vmax=20, levels=[2*i for i in range(11)],extent=(grid_9_9ns_multiT[0][0,:].min(),grid_9_9ns_multiT[0][0,:].max(),grid_9_9ns_multiT[1][:,0].min(),grid_9_9ns_multiT[1][:,0].max()))
cbar = plt.colorbar(pp)
plt.xlim(-0.9,1.2)
plt.ylim(-1.2,0.75)
cbar.set_label("FES")
plt.xlabel("Deep-TICA Lasso1")  # Set x-axis label
plt.ylabel("Deep-TICA Lasso2")  
#plt.savefig('fes_ourcv_mod.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
#DE Shaw
df = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/DE_Shaw_analysis_mod_final/COLVAR_torsion_multiT_SCV_lowT',stride=1)


cv = df.filter(regex='lassoCV_node0|lassoCV_node1').values

fes_deS,grid_deS,bounds_deS,error_deS = compute_fes(cv,				                    
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=False, eps=1e-10)

# %%
pp = plt.contourf(fes_deS, cmap="fessa", vmax=20, levels=[2*i for i in range(11)],extent=(grid_deS[0][0,:].min(),grid_deS[0][0,:].max(),grid_deS[1][:,0].min(),grid_deS[1][:,0].max()))
cbar = plt.colorbar(pp)
plt.xlim(-0.9,1.2)
plt.ylim(-1.2,0.75)
plt.xlabel("Deep-TICA Lasso1")  # Set x-axis label
plt.ylabel("Deep-TICA Lasso2")  
cbar.set_label("FES")
plt.savefig('fes_ourcv_indeshaw_mod.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
#DE Shaw
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes
import pandas as pd
df = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/DE_Shaw_analysis_mod_final/COLVAR_torsion_NN_multiT',stride=1)


cv = df.filter(regex='DeepTICA.node-0|DeepTICA.node-1').values
cv[:,0] = -cv[:,0]

fes_deS_NN_multiT,grid_deS_NN_multiT,bounds_deS_NN_multiT,error_deS_NN_multiT = compute_fes(cv,				                    
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=False, eps=1e-10)

pp = plt.contourf(fes_deS_NN_multiT, cmap="fessa", vmax=20, levels=[2*i for i in range(11)],extent=(grid_deS_NN_multiT[0][0,:].min(),grid_deS_NN_multiT[0][0,:].max(),grid_deS_NN_multiT[1][:,0].min(),grid_deS_NN_multiT[1][:,0].max()))
cbar = plt.colorbar(pp)
plt.xlim(-0.9,1.2)
plt.ylim(-1.2,0.75)
cbar.set_label("FES")
plt.xlabel("Deep-TICA 1")  # Set x-axis label
plt.ylabel("Deep-TICA 2") 
plt.savefig('fes_ourcv_indeshaw_mod_aaaa_multiCV_NN.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

l1 = np.loadtxt('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_10ns/deltaF.dat')
l2 = np.loadtxt('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_9.7ns/deltaF.dat')
l3 = np.loadtxt('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_9.9ns/deltaF.dat')

print(l1.shape)
print(l2.shape)
print(l3.shape)

# Multiplying the arrays by -1
#l1 = l1 * -1
#l2 = l2 * -1
#l3 = l3 * -1

Fmean = np.mean(np.vstack((l1,l2,l3)),axis=0)
print(Fmean.shape)

Fstd = np.std(np.vstack((l1,l2,l3)),axis=0)

xx = np.arange(len(Fmean))*0.01


plt.figure(figsize=(6,2))
plt.ylim(-10,20)


plt.fill_between(xx,Fmean-Fstd,Fmean+Fstd,color='xkcd:lightgreen',alpha=0.5)

#plt.plot(xx,l1,color='g',lw=1)
#plt.plot(xx,l3,color='g',lw=1)
#plt.plot(xx,l2,color='g',lw=1)
plt.plot(xx,Fmean,color='g',lw=1)

#reference = 4.1855*0.9 #kJ/mol
reference = 7.70
plt.plot(xx,np.ones(len(xx))*reference,'k--',label='Reference')
plt.plot(xx,np.ones(len(xx))*(reference+2.5),color='k',ls=':',label='Reference')
plt.plot(xx,np.ones(len(xx))*(reference-2.5),color='k',ls=':')
plt.xlabel('Simulation Time ($\mu$s)',fontsize=16)
plt.ylabel('$\Delta F$ (kJ/mol)',fontsize=16)

plt.xticks(fontsize=14)
#plt.xticks([0, 0.75, 1.5, 2.25], ['0.25', '1.0', '1.75', '2.50'], fontsize=14)
plt.xticks([0, 0.3, 0.6, 0.9], ['0.1', '0.4', '0.7', '1'], fontsize=14)
plt.yticks(fontsize=14)

plt.title('Surrogate Model CV',fontsize=16)
plt.savefig('AAAA_conv_multiTCV-correct.png',dpi=300,bbox_inches='tight')
# Out:
# (90,)
# (90,)
# (90,)
# (90,)

# %%
#DE Shaw
from mlcolvar.utils.fes import compute_fes
df = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/DE_Shaw_analysis_mod_final/COLVAR_torsion_multiT_SCV_lowT',stride=1)


cv = df.filter(regex='lassoCV_node0').values

fes_deS_1D,grid_deS_1D,bounds_deS_1D,error_deS_1D = compute_fes(cv,				                    
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=False, eps=1e-10)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes
import pandas as pd


# load colvar files containing weights of the OPES simulations as well as the driver with the input features
opes = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_10ns_mod_final/COLVAR',
    start=100000, stop=1000000, stride=10)

feat = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_10ns_mod_final/COLVAR_driver',
    start=10000, stop=100000, stride=1)



bias = opes.filter(regex='.bias').values.sum(axis=1)

cv = feat.filter(regex='lassoCV_node0').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

#fig,ax = plt.subplots(1,1,figsize=(6,5),dpi=100)



fes_10ns_1D,grid_10ns_1D,bounds_10ns_1D,error_10ns_1D = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=False, eps=1e-10)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes
import pandas as pd


# load colvar files containing weights of the OPES simulations as well as the driver with the input features
opes = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_9.7ns_mod_final/COLVAR',
    start=100000, stop=1000000, stride=10)

feat = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_9.7ns_mod_final/COLVAR_driver',
    start=10000, stop=100000, stride=1)



bias = opes.filter(regex='.bias').values.sum(axis=1)

cv = feat.filter(regex='lassoCV_node0').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

#fig,ax = plt.subplots(1,1,figsize=(6,5),dpi=100)



fes_9_7ns_1D,grid_9_7ns_1D,bounds_9_7ns_1D,error_9_7ns_1D = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=False, eps=1e-10)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes
import pandas as pd


# load colvar files containing weights of the OPES simulations as well as the driver with the input features
opes = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_9.9ns_mod_final/COLVAR',
    start=100000, stop=1000000, stride=10)

feat = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/OPES_lasso_9.9ns_mod_final/COLVAR_driver',
    start=10000, stop=100000, stride=1)



bias = opes.filter(regex='.bias').values.sum(axis=1)

cv = feat.filter(regex='lassoCV_node0').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

#fig,ax = plt.subplots(1,1,figsize=(6,5),dpi=100)



fes_9_9ns_1D,grid_9_9ns_1D,bounds_9_9ns_1D,error_9_9ns_1D = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=False, eps=1e-10)

# %%
fes_mean_1D = np.mean([fes_10ns_1D, fes_9_7ns_1D, fes_9_9ns_1D], axis=0)
fes_std = np.std([fes_10ns_1D, fes_9_7ns_1D, fes_9_9ns_1D], axis=0)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes

#df = load_dataframe('COLVAR',start=50000,stop=1279880,stride=1)
df = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_10ns/COLVAR',stride=1,start=100000,stop=1000000)

bias = df.filter(regex='opes.bias').values.sum(axis=1)

cv = df.filter(regex='lassoCV_node0').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

fes_10ns_multiT_1D,grid_10ns_multiT_1D,bounds_10ns_multiT_1D,error_10ns_multiT_1D = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=False, eps=1e-10)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes

#df = load_dataframe('COLVAR',start=50000,stop=1279880,stride=1)
df = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_9.7ns/COLVAR',stride=1,start=100000,stop=1000000)

bias = df.filter(regex='opes.bias').values.sum(axis=1)

cv = df.filter(regex='lassoCV_node0').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

fes_9_7ns_multiT_1D,grid_9_7ns_multiT_1D,bounds_9_7ns_multiT_1D,error_9_7ns_multiT_1D = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=False, eps=1e-10)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mlcolvar.utils.plot import plot_metrics
from mlcolvar.utils.io import load_dataframe
from mlcolvar.utils.fes import compute_fes

#df = load_dataframe('COLVAR',start=50000,stop=1279880,stride=1)
df = load_dataframe('/home/sompriya/Desktop/RNA_tetranucleotides/AAAA/DESRES-Trajectory_pnas2018-tetranucleotide-AAAA-no-water/pnas2018-tetranucleotide-AAAA-no-water/large_WBOX/opes_frm_multiT_lowT_withoutstatic_1us_9.9ns/COLVAR',stride=1,start=100000,stop=1000000)

bias = df.filter(regex='opes.bias').values.sum(axis=1)

cv = df.filter(regex='lassoCV_node0').values

# Calculate inverse temperature
temp=275.0
kb=0.008314
beta=1./(kb*temp)

# Compute log-weights for reweighting
logweights = beta*bias
w = np.exp(logweights)

fes_9_9ns_multiT_1D,grid_9_9ns_multiT_1D,bounds_9_9ns_multiT_1D,error_9_9ns_multiT_1D = compute_fes(cv,
				                    weights=w,
                                    blocks=1,
                                    bandwidth=0.01, scale_by='range',
                                    plot=False, eps=1e-10)

# %%
fes_mean_multiT_1D = np.mean([fes_10ns_multiT_1D, fes_9_7ns_multiT_1D, fes_9_9ns_multiT_1D], axis=0)
fes_multiT_std = np.std([fes_10ns_multiT_1D, fes_9_7ns_multiT_1D, fes_9_9ns_multiT_1D], axis=0)

# %%
plt.figure(figsize=(6, 4))

plt.plot(grid_deS_1D,fes_deS_1D,color='black',lw=1, ls='--',label='Unbiased Reference')

#plt.plot(grid_9_7ns_1D,fes_9_7ns_1D,color='blue', lw=5, alpha=0.5)
#plt.plot(grid_10ns_multiT_1D,fes_10ns_multiT_1D,color='green', lw=5, alpha=0.5)
#plt.plot(grid_9_9ns_1D,fes_9_9ns_1D,color='orange', lw=5, alpha=0.5)

plt.plot(grid_9_7ns_1D,fes_mean_1D,color='green', ls='-', lw=2, alpha=0.5, label= 'CV Trained on Unbiased Simulation')
plt.fill_between(grid_9_7ns_1D, fes_mean_1D - fes_std, fes_mean_1D + fes_std, color='xkcd:lightgreen', alpha=0.3)

plt.plot(grid_10ns_multiT_1D,fes_mean_multiT_1D,color='blue', ls='-', lw=2, alpha=0.5,label= 'CV Trained on Multithermal Simulation')
plt.fill_between(grid_10ns_multiT_1D, fes_mean_multiT_1D - fes_multiT_std, fes_mean_multiT_1D + fes_multiT_std, color='xkcd:lightblue', alpha=0.3)

plt.legend(fontsize=10)


plt.ylim(0,25)
plt.xlim(-1,1)
plt.xlabel('Explainable Deep-TICA CV',fontsize=16)
plt.ylabel('FES (kJ/mol)',fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.savefig('1d_lasso0_AAAA',dpi=300,bbox_inches='tight')
plt.show()
